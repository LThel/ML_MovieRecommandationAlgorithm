# %%
import pandas as pd

# %%
pd.read_csv("dataframes\maxi_filtered_df3000.csv")
# Out:
#       Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1   index  Unnamed: 0  \
# 0            15982         16362         65275   84003       84003
# 1            24919         26788        147662  244065      244065
# 2            31579         34482        187270  376251      376251
# 3            18171         18688         76369  100094      100094
# 4            15751         16117         64386   82954       82954
# ...            ...           ...           ...     ...         ...
# 2995         30279         33009        178322  343410      343410
# 2996         21611         22865        121292  186402      186402
# 2997         37854         42059        231068  541564      541564
# 2998         31502         34399        186741  374044      374044
# 2999         35979         39755        217557  488620      488620
#
#           tconst titleType                primaryTitle  \
# 0      tt0111161     movie    The Shawshank Redemption
# ...
